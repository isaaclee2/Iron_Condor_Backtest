# %%
import zstandard as zstd
import pandas as pd

# DTE = 3
# CALL_DELTA_TARGET = 0.03
# PUT_DELTA_TARGET = 0.06
# SPREAD = 150


# df = pd.read_csv('/Users/isaaclee/quant_internship/SPXW_minute_split/20250715/103000.csv.zst', compression='zstd')

# df_exp = df[df['expiration'] == 20250718]
# df_exp = df_exp[df_exp['option_type'] == 'C']

# df_exp


# # portfolio value time series
# # risk metrics, juice worth the squeeze
# # portfolio sizing


# # refinement idea: 
# # 1. (ML) given macro/micro market data, predict best parameters for iron condor for next day. Dataset would look like: market data, target value is parameters. Training data would have optimal parameters for market conditions
# #     may have to write a script to generate this data
# # 2. find market conditions or pretty much anything that correlates in the future with iron condor profitability.


# value of options at portfolio
# 1600 (time) for value of options
# mark portfolio to market
# data processing with new vendor

# %%
import csv
INITIAL_CAPITAL = 100000

def daily_portfolio_timeseries(ic_df, initial_capital=INITIAL_CAPITAL):
    portfolio_start = ic_df['entry_date'].min()
    portfolio_end = ic_df['expiration_date'].max()
    
    

ic_df = pd.read_csv('iron_condor_trades_data.csv')
daily_portfolio_timeseries(ic_df)
