# %%
import pandas as pd

df = pd.read_csv(f'/Users/isaaclee/overture/SPXW_minute_split/20250708/160000.csv.zst', compression='zstd')
df
# Out:
#        root  expiration  strike option_type  bid_size      bid  ask_size  \
# 0      SPXW    20250708    2400           C         5  3816.40         1
# 1      SPXW    20250708    2400           P         0     0.00     13765
# 2      SPXW    20250708    2600           C         1  3616.20         1
# 3      SPXW    20250708    2600           P         0     0.00      3777
# 4      SPXW    20250708    2800           C         1  3416.20         1
# ...     ...         ...     ...         ...       ...      ...       ...
# 19911   SPX    20301220   10000           P         1  2258.80         1
# 19912   SPX    20301220   11000           C         7   108.80        31
# 19913   SPX    20301220   11000           P         0     0.00         0
# 19914   SPX    20301220   12000           C         1    65.00         1
# 19915   SPX    20301220   12000           P         1     0.05         0
#
#            ask  implied_volatility   delta   gamma   theta     vega       rho
# ...

# %%
df = pd.read_csv(f'/Volumes/SSD/SPX_2019/UnderlyingOptionsIntervals_60sec_calcs_oi_2019-01-02.csv.zst', compression='zstd')
df
# Out:
#         underlying_symbol       quote_datetime  root  expiration  strike  \
# 0                    ^SPX  2019-01-02 09:31:00   SPX  2019-01-18   750.0
# 1                    ^SPX  2019-01-02 09:32:00   SPX  2019-01-18   750.0
# 2                    ^SPX  2019-01-02 09:33:00   SPX  2019-01-18   750.0
# 3                    ^SPX  2019-01-02 09:34:00   SPX  2019-01-18   750.0
# 4                    ^SPX  2019-01-02 09:35:00   SPX  2019-01-18   750.0
# ...                   ...                  ...   ...         ...     ...
# 6120355              ^SPX  2019-01-02 16:11:00  SPXW  2019-12-31  3600.0
# 6120356              ^SPX  2019-01-02 16:12:00  SPXW  2019-12-31  3600.0
# 6120357              ^SPX  2019-01-02 16:13:00  SPXW  2019-12-31  3600.0
# 6120358              ^SPX  2019-01-02 16:14:00  SPXW  2019-12-31  3600.0
# 6120359              ^SPX  2019-01-02 16:15:00  SPXW  2019-12-31  3600.0
#
#         option_type  open  high  low  close  ...  underlying_ask  \
# ...

# %%
df = pd.read_csv('/Volumes/SSD/thetadata_sample/OPTION/SPX/SPX_quote_1m.csv')
df


#1.23
#1.33/34

# maybe chapter 9

# 10.4
# A bit of 11
